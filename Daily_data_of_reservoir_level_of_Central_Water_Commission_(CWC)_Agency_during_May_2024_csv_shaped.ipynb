# %% [markdown]
# # Data Analytics Project
# This notebook provides a basic structure for performing data analytics on the provided dataset.

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# Load the dataset
file_path = '/content/drive/My Drive/Water.csv'  # Change this path to match your file location in Google Drive
df = pd.read_csv(file_path)

# Display the first few rows of the dataset
df.head()
# Out:
# Mounted at /content/drive
#           Reservoir_name        Basin      Subbasin Agency_name        Lat  \
# 0  ATAL SAGAR(MADIKHEDA)  Ganga Basin  Yamuna Lower         CWC  25.555556
# 1  ATAL SAGAR(MADIKHEDA)  Ganga Basin  Yamuna Lower         CWC  25.555556
# 2  ATAL SAGAR(MADIKHEDA)  Ganga Basin  Yamuna Lower         CWC  25.555556
# 3  ATAL SAGAR(MADIKHEDA)  Ganga Basin  Yamuna Lower         CWC  25.555556
# 4  ATAL SAGAR(MADIKHEDA)  Ganga Basin  Yamuna Lower         CWC  25.555556
#
#         Long        Date  Year  Month  Full_reservoir_level  \
# 0  77.852778  2024-05-01  2024      5                346.25
# 1  77.852778  2024-05-02  2024      5                346.25
# 2  77.852778  2024-05-03  2024      5                346.25
# 3  77.852778  2024-05-04  2024      5                346.25
# 4  77.852778  2024-05-05  2024      5                346.25
#
#    Live_capacity_FRL  Storage  Level
# 0              0.835      NaN    NaN
# 1              0.835  0.15745  329.8
# ...

# %% [markdown]
# ## Basic Information

# %%
# Basic information about the dataset
df.info()

# Summary statistics
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4618 entries, 0 to 4617
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Reservoir_name        4618 non-null   object
#  1   Basin                 4618 non-null   object
#  2   Subbasin              4618 non-null   object
#  3   Agency_name           4618 non-null   object
#  4   Lat                   4618 non-null   float64
#  5   Long                  4618 non-null   float64
#  6   Date                  4618 non-null   object
#  7   Year                  4618 non-null   int64
#  8   Month                 4618 non-null   int64
#  9   Full_reservoir_level  4618 non-null   float64
#  10  Live_capacity_FRL     4618 non-null   float64
#  11  Storage               2969 non-null   float64
#  12  Level                 3024 non-null   float64
# dtypes: float64(6), int64(2), object(5)
# memory usage: 469.1+ KB
# ...

# %% [markdown]
# ## Checking for Missing Values

# %%
# Checking for missing values
df.isnull().sum()

# Visualizing missing values (if any)
sns.heatmap(df.isnull(), cbar=False, cmap='viridis')
# Out:
# <Axes: >

# %% [markdown]
# ## Data Preprocessing

# %% [markdown]
# ## Data Visualization

# %%
# Visualizing data distributions
df.hist(bins=30, figsize=(20, 15))
plt.show()

# %% [markdown]
# ## Further Analysis

# %%
# Further analysis (e.g., feature engineering, clustering, etc.)
# Example: Pairplot for visualizing relationships
sns.pairplot(df)
plt.show()

# Saving the preprocessed dataset (optional)
df.to_csv('/content/drive/My Drive/preprocessed_Water.csv', index=False)
